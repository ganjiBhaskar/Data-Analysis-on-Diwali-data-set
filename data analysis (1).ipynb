# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Ganji Bhaskar\Downloads\Diwali_Sales_Data.csv",encoding="unicode_escape")

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11239.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9453.610858
# std    1.716125e+03     12.754122        0.493632      1.115047   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
df.isna().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df["Amount"].fillna(df["Amount"].mean(),inplace=True)

# %%
df.isna().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 8

# %%
df.drop_duplicates(keep="first",inplace=True)

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.124300e+04  11243.000000    11243.000000  11243.000000  11243.000000
# mean   1.003005e+06     35.422841        0.420261      2.488749   9454.084476
# std    1.716141e+03     12.756369        0.493623      1.114960   5218.941128
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001494e+06     27.000000        0.000000      1.000000   5444.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8111.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12672.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
df["Age"].plot(kind="hist")
plt.xlabel("Age")
plt.title("Histogram of age")
# Out:
# Text(0.5, 1.0, 'Histogram of age')

# %% [markdown]
# the above one represents the Histogram of the age
#
# the more numbers are from the age of 30-35 years of the age
#
# the numbers are from the 60 to 90 years of the age

# %%
df["Age"].plot(kind="density")
plt.xlabel("Age")
plt.title("density of age")
# Out:
# Text(0.5, 1.0, 'density of age')

# %% [markdown]
# At the age of 35 there are more numbers

# %%
df["Age"].plot(kind="box")
plt.xlabel("Age")
plt.title("density of age")
# Out:
# Text(0.5, 1.0, 'density of age')

# %% [markdown]
# from the above plot we can see there are outliers
#
# the above 67 years of the age are the outliers

# %%
q1=df["Age"].quantile(0.25)
q1
# Out:
# 27.0

# %%
q3=df["Age"].quantile(0.75)
q3
# Out:
# 43.0

# %%
IQR=q3-q1
IQR
# Out:
# 16.0

# %%
lower=q1-(1.5*IQR)
lower
# Out:
# 3.0

# %%
upper=q3+(1.5*IQR)
upper
# Out:
# 67.0

# %%
cond=((df["Age"]<lower)|(df["Age"]>upper))

# %%
cond.sum()
# Out:
# 283

# %%
df[cond]
# Out:
#        User_ID Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 24     1000900    Skaria  P00317842      M       55+   83               0
# 38     1002520      Mike  P00310342      M       55+   72               1
# 197    1001736  Martinez  P00227942      M       55+   72               1
# 234    1002201    Dodson  P00127642      F       55+   83               1
# 275    1002760   McClure  P00101842      M       55+   77               1
# ...        ...       ...        ...    ...       ...  ...             ...
# 11107  1002111     Vipul  P00120142      F       55+   85               0
# 11125  1002634     Gross  P00073642      F       55+   76               0
# 11148  1002002   Maureen  P00177442      M       55+   89               0
# 11162  1005223   Nandita  P00059642      F       55+   69               0
# 11229  1000188     Khloe  P00080342      F       55+   80               0
#
#                   State      Zone  Occupation  Product_Category  Orders  \
# ...

# %%
a=np.floor(df["Age"].mean())

# %%
df["Age"]=np.where(cond,a,df["Age"])

# %%
df["Age"].plot(kind="box")
plt.xlabel("Age")
plt.title("density of age")
# Out:
# Text(0.5, 1.0, 'density of age')

# %% [markdown]
# from the above plot we can see there are outliers but when we compare to the above graph there are less outliers
#
# the above 67 years of the age are the outliers

# %%
q1=df["Age"].quantile(0.25)
q1
# Out:
# 27.0

# %%
q3=df["Age"].quantile(0.75)
q3
# Out:
# 42.0

# %%
IQR=q3-q1
IQR
# Out:
# 15.0

# %%
lower=q1-(1.5*IQR)
lower
# Out:
# 4.5

# %%
upper=q3+(1.5*IQR)
upper
# Out:
# 64.5

# %%
cond=((df["Age"]<lower)|(df["Age"]>upper))

# %%
cond.sum()
# Out:
# 36

# %%
df[cond]
# Out:
#        User_ID   Cust_name Product_ID Gender Age Group   Age  Marital_Status  \
# 124    1001896    Brittain  P00117142      M       55+  66.0               0
# 458    1000725   Goranitis  P00093242      F       55+  67.0               1
# 545    1005221      Yogesh  P00346642      M       55+  67.0               0
# 671    1002016   Manibalan  P00139942      M       55+  67.0               0
# 788    1005517    Priyanka  P00246942      F       55+  66.0               1
# 950    1003897      Gayman  P00116342      F       55+  66.0               0
# 1042   1004802       Patil  P00212942      F       55+  67.0               0
# 1871   1004802       Patil  P00089242      F       55+  65.0               0
# 1981   1004156   Christine  P00066542      F       55+  67.0               0
# 2375   1002483     Aarushi  P00313442      F       55+  66.0               0
# 3085   1000090  Rittenbach  P00192842      M       55+  65.0               0
# ...

# %%
B=np.floor(df["Age"].mean())

# %%
df["Age"]=np.where(cond,B,df["Age"])

# %%
df["Age"].plot(kind="box")

plt.title("density of age")
# Out:
# Text(0.5, 1.0, 'density of age')

# %% [markdown]
# Now from above graph we can see there are no outliers

# %%
q1=df["Age"].quantile(0.25)
q1
# Out:
# 27.0

# %%
q3=df["Age"].quantile(0.75)
q3
# Out:
# 42.0

# %%
IQR=q3-q1
IQR
# Out:
# 15.0

# %%
lower=q1-(1.5*IQR)
lower
# Out:
# 4.5

# %%
upper=q3+(1.5*IQR)
upper
# Out:
# 64.5

# %%
cond=((df["Age"]<lower)|(df["Age"]>upper))

# %%
cond.sum()
# Out:
# 0

# %%
df[cond]
# Out:
# Empty DataFrame
# Columns: [User_ID, Cust_name, Product_ID, Gender, Age Group, Age, Marital_Status, State, Zone, Occupation, Product_Category, Orders, Amount]
# Index: []

# %%
df["Age"].plot(kind="hist")
plt.xlabel("Age")
plt.title("Histogram of age")
# Out:
# Text(0.5, 1.0, 'Histogram of age')

# %% [markdown]
# the more numbers are from the age of 27 to 34 years of the age

# %%
df["Age"].plot(kind="density")
plt.xlabel("Age")
plt.title("density of age")
# Out:
# Text(0.5, 1.0, 'density of age')

# %%
df["Age"].plot(kind="box")

plt.title("density of age")
# Out:
# Text(0.5, 1.0, 'density of age')

# %% [markdown]
# now there are no outliers in it

# %%
sns.distplot(df["Age"],
            color="#4f0620")
# Out:
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\3319182232.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"],
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df["Amount"].plot(kind="hist")
plt.xlabel("Amount")
plt.title("Histogram of Amount")
# Out:
# Text(0.5, 1.0, 'Histogram of Amount')

# %% [markdown]
# the more amount is around the 5000 to 1000
#
# the less amount of the data is around the amount of 22000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11243 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11243 non-null  int64
#  1   Cust_name         11243 non-null  object
#  2   Product_ID        11243 non-null  object
#  3   Gender            11243 non-null  object
#  4   Age Group         11243 non-null  object
#  5   Age               11243 non-null  float64
#  6   Marital_Status    11243 non-null  int64
#  7   State             11243 non-null  object
#  8   Zone              11243 non-null  object
#  9   Occupation        11243 non-null  object
#  10  Product_Category  11243 non-null  object
#  11  Orders            11243 non-null  int64
#  12  Amount            11243 non-null  float64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 1.2+ MB

# %%
df["Amount"].plot(kind="density")
plt.xlabel("Amount")
plt.title("density of Amount")
# Out:
# Text(0.5, 1.0, 'density of Amount')

# %% [markdown]
# from the above density graph we can see that more amount of the data is around 9000

# %%
df["Amount"].plot(kind="box")

plt.title("density of Amount")
# Out:
# Text(0.5, 1.0, 'density of Amount')

# %%
Q1=df["Amount"].quantile(0.25)
Q1
# Out:
# 5444.0

# %%
Q3=df["Amount"].quantile(0.75)
Q3
# Out:
# 12672.0

# %%
Iqr=Q3-Q1
Iqr
# Out:
# 7228.0

# %%
lower=Q1-(1.5*Iqr)
lower
# Out:
# -5398.0

# %%
upper=Q3+(1.5*Iqr)
upper
# Out:
# 23514.0

# %%
cond=((df["Amount"]<lower)|(df["Amount"]>upper))

# %%
cond.sum()
# Out:
# 20

# %%
df[cond]
# Out:
#     User_ID    Cust_name Product_ID Gender Age Group   Age  Marital_Status  \
# 0   1002903    Sanskriti  P00125942      F     26-35  28.0               0
# 1   1000732       Kartik  P00110942      F     26-35  35.0               1
# 2   1001990        Bindu  P00118542      F     26-35  35.0               1
# 3   1001425       Sudevi  P00237842      M      0-17  16.0               0
# 4   1000588         Joni  P00057942      M     26-35  28.0               1
# 5   1000588         Joni  P00057942      M     26-35  28.0               1
# 6   1001132         Balk  P00018042      F     18-25  25.0               1
# 8   1003224       Kushal  P00205642      M     26-35  35.0               0
# 9   1003650        Ginny  P00031142      F     26-35  26.0               1
# 10  1003829     Harshita  P00200842      M     26-35  34.0               0
# 11  1000214     Kargatis  P00119142      F     18-25  20.0               0
# ...

# %%
b=np.floor(df["Amount"].mean())

# %%
df["Amount"]=np.where(cond,b,df["Amount"])

# %%
df["Amount"].plot(kind="box")

plt.title("density of Amount")
# Out:
# Text(0.5, 1.0, 'density of Amount')

# %%
Q1=df["Amount"].quantile(0.25)
Q1
# Out:
# 5444.0

# %%
Q3=df["Amount"].quantile(0.75)
Q3
# Out:
# 12622.5

# %%
Iqr=Q3-Q1
Iqr
# Out:
# 7178.5

# %%
lower=Q1-(1.5*Iqr)
lower
# Out:
# -5323.75

# %%
upper=Q3+(1.5*Iqr)
upper
# Out:
# 23390.25

# %%
cond=((df["Amount"]<lower)|(df["Amount"]>upper))

# %%
cond.sum()
# Out:
# 5

# %%
df[cond]
# Out:
#     User_ID Cust_name Product_ID Gender Age Group   Age  Marital_Status  \
# 24  1000900    Skaria  P00317842      M       55+  35.0               0
# 25  1005908      Eric  P00282642      F     26-35  33.0               0
# 26  1001101    Gibson  P00234742      F     36-45  40.0               0
# 27  1004736    Mahima  P00058042      F     18-25  25.0               1
# 28  1004037   Etezadi  P00190542      M     51-55  54.0               1
#
#              State      Zone  Occupation    Product_Category  Orders   Amount
# 24       Karnataka  Southern  Automobile                Auto       3  23513.0
# 25  Andhra Pradesh  Southern   IT Sector                Auto       3  23462.0
# 26   Uttar Pradesh   Central     Banking                Auto       3  23456.0
# 27  Andhra Pradesh  Southern     Banking                Auto       4  23451.0
# 28  Andhra Pradesh  Southern        Govt  Hand & Power Tools       2  23434.0

# %%
c=np.floor(df["Amount"].mean())
c
# Out:
# 9428.0

# %%
df["Amount"]=np.where(cond,c,df["Amount"])

# %%
df["Amount"].plot(kind="box")

plt.title("density of Amount")
# Out:
# Text(0.5, 1.0, 'density of Amount')

# %%
Q1=df["Amount"].quantile(0.25)
Q1
# Out:
# 5444.0

# %%
Q3=df["Amount"].quantile(0.75)
Q3
# Out:
# 12611.5

# %%
Iqr=Q3-Q1
Iqr
# Out:
# 7167.5

# %%
lower=Q1-(1.5*Iqr)
lower
# Out:
# -5307.25

# %%
upper=Q3+(1.5*Iqr)
upper
# Out:
# 23362.75

# %%
cond=((df["Amount"]<lower)|(df["Amount"]>upper))

# %%
cond.sum()
# Out:
# 2

# %%
df[cond]
# Out:
#     User_ID Cust_name Product_ID Gender Age Group   Age  Marital_Status  \
# 29  1002340     James  P00119642      F     36-45  39.0               1
# 30  1005664      Dean  P00111642      F     18-25  20.0               0
#
#              State      Zone Occupation Product_Category  Orders   Amount
# 29  Andhra Pradesh  Southern   Aviation             Auto       3  23389.0
# 30  Andhra Pradesh  Southern   Aviation             Auto       2  23365.0

# %%
d=np.floor(df["Amount"].mean())
d
# Out:
# 9422.0

# %%
df["Amount"]=np.where(cond,d,df["Amount"])

# %%
df["Amount"].plot(kind="box")

plt.title("density of Amount")
# Out:
# Text(0.5, 1.0, 'density of Amount')

# %% [markdown]
# from the above box plot we can see there are no outliers

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group   Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35  28.0               0
# 1      1000732       Kartik  P00110942      F     26-35  35.0               1
# 2      1001990        Bindu  P00118542      F     26-35  35.0               1
# 3      1001425       Sudevi  P00237842      M      0-17  16.0               0
# 4      1000588         Joni  P00057942      M     26-35  28.0               1
# ...        ...          ...        ...    ...       ...   ...             ...
# 11246  1000695      Manning  P00296942      M     18-25  19.0               1
# 11247  1004089  Reichenbach  P00171342      M     26-35  33.0               0
# 11248  1001209        Oshin  P00201342      F     36-45  40.0               0
# 11249  1004023       Noonan  P00059442      M     36-45  37.0               0
# 11250  1002744      Brumley  P00281742      F     18-25  19.0               0
#
# ...

# %%
def gender(x):
    if x=='F':
        return "Female"
    else:
        return "Male"

# %%
df["Gender"]=df["Gender"].apply(gender)

# %%
df
# Out:
#        User_ID    Cust_name Product_ID  Gender Age Group   Age  \
# 0      1002903    Sanskriti  P00125942  Female     26-35  28.0
# 1      1000732       Kartik  P00110942  Female     26-35  35.0
# 2      1001990        Bindu  P00118542  Female     26-35  35.0
# 3      1001425       Sudevi  P00237842    Male      0-17  16.0
# 4      1000588         Joni  P00057942    Male     26-35  28.0
# ...        ...          ...        ...     ...       ...   ...
# 11246  1000695      Manning  P00296942    Male     18-25  19.0
# 11247  1004089  Reichenbach  P00171342    Male     26-35  33.0
# 11248  1001209        Oshin  P00201342  Female     36-45  40.0
# 11249  1004023       Noonan  P00059442    Male     36-45  37.0
# 11250  1002744      Brumley  P00281742  Female     18-25  19.0
#
#        Marital_Status           State      Zone       Occupation  \
# 0                   0     Maharashtra   Western       Healthcare
# 1                   1  Andhra Pradesh  Southern             Govt
# ...

# %%
def Marital_Status(x):
    if x==0:
        return "Married"
    else:
        return "Unmarried"

# %%
df["Marital_Status"]=df["Marital_Status"].apply(Marital_Status)

# %%
df
# Out:
#        User_ID    Cust_name Product_ID  Gender Age Group   Age Marital_Status  \
# 0      1002903    Sanskriti  P00125942  Female     26-35  28.0        Married
# 1      1000732       Kartik  P00110942  Female     26-35  35.0      Unmarried
# 2      1001990        Bindu  P00118542  Female     26-35  35.0      Unmarried
# 3      1001425       Sudevi  P00237842    Male      0-17  16.0        Married
# 4      1000588         Joni  P00057942    Male     26-35  28.0      Unmarried
# ...        ...          ...        ...     ...       ...   ...            ...
# 11246  1000695      Manning  P00296942    Male     18-25  19.0      Unmarried
# 11247  1004089  Reichenbach  P00171342    Male     26-35  33.0        Married
# 11248  1001209        Oshin  P00201342  Female     36-45  40.0        Married
# 11249  1004023       Noonan  P00059442    Male     36-45  37.0        Married
# 11250  1002744      Brumley  P00281742  Female     18-25  19.0        Married
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11243 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11243 non-null  int64
#  1   Cust_name         11243 non-null  object
#  2   Product_ID        11243 non-null  object
#  3   Gender            11243 non-null  object
#  4   Age Group         11243 non-null  object
#  5   Age               11243 non-null  float64
#  6   Marital_Status    11243 non-null  object
#  7   State             11243 non-null  object
#  8   Zone              11243 non-null  object
#  9   Occupation        11243 non-null  object
#  10  Product_Category  11243 non-null  object
#  11  Orders            11243 non-null  int64
#  12  Amount            11243 non-null  float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.2+ MB

# %%
df.describe()
# Out:
#             User_ID           Age        Orders        Amount
# count  1.124300e+04  11243.000000  11243.000000  11243.000000
# mean   1.003005e+06     34.189273      2.488749   9419.942611
# std    1.716141e+03     10.345969      1.114960   5172.152278
# min    1.000001e+06     12.000000      1.000000    188.000000
# 25%    1.001494e+06     27.000000      1.000000   5444.000000
# 50%    1.003065e+06     33.000000      2.000000   8111.000000
# 75%    1.004430e+06     42.000000      3.000000  12609.000000
# max    1.006040e+06     64.000000      4.000000  23326.000000

# %%
df.describe(include="object")
# Out:
#        Cust_name Product_ID  Gender Age Group Marital_Status          State  \
# count      11243      11243   11243     11243          11243          11243
# unique      1250       2351       2         7              2             16
# top     Vishakha  P00265242  Female     26-35        Married  Uttar Pradesh
# freq          42         53    7838      4538           6518           1944
#
#            Zone Occupation    Product_Category
# count     11243      11243               11243
# unique        5         15                  18
# top     Central  IT Sector  Clothing & Apparel
# freq       4294       1586                2653

# %%
df["Gender"].value_counts().plot(kind="bar",color=["red","green"],width=0.3)
plt.xticks(rotation=0)
plt.xlabel("Gender")
plt.title("barplot of Gender")
# Out:
# Text(0.5, 1.0, 'barplot of Gender')

# %% [markdown]
# from the above bar plot we can say that females are more when compared to the male

# %%
custom_palette = sns.color_palette("husl", 4)

# %%
sns.countplot(data=df,x="Gender",width=0.3,palette=custom_palette)
plt.title("count plot of gender")
plt.show()
# Out:
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\2509913955.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x="Gender",width=0.3,palette=custom_palette)
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\2509913955.py:1: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.countplot(data=df,x="Gender",width=0.3,palette=custom_palette)

# %%
df["Gender"].value_counts().plot(kind="pie",autopct="%1.2f")
plt.xlabel("Gender")
plt.title("pie chart of Gender")
# Out:
# Text(0.5, 1.0, 'pie chart of Gender')

# %% [markdown]
# the female count is 69.71% and male count is 30.29%

# %%
df
# Out:
#        User_ID    Cust_name Product_ID  Gender Age Group   Age Marital_Status  \
# 0      1002903    Sanskriti  P00125942  Female     26-35  28.0        Married
# 1      1000732       Kartik  P00110942  Female     26-35  35.0      Unmarried
# 2      1001990        Bindu  P00118542  Female     26-35  35.0      Unmarried
# 3      1001425       Sudevi  P00237842    Male      0-17  16.0        Married
# 4      1000588         Joni  P00057942    Male     26-35  28.0      Unmarried
# ...        ...          ...        ...     ...       ...   ...            ...
# 11246  1000695      Manning  P00296942    Male     18-25  19.0      Unmarried
# 11247  1004089  Reichenbach  P00171342    Male     26-35  33.0        Married
# 11248  1001209        Oshin  P00201342  Female     36-45  40.0        Married
# 11249  1004023       Noonan  P00059442    Male     36-45  37.0        Married
# 11250  1002744      Brumley  P00281742  Female     18-25  19.0        Married
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11243 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11243 non-null  int64
#  1   Cust_name         11243 non-null  object
#  2   Product_ID        11243 non-null  object
#  3   Gender            11243 non-null  object
#  4   Age Group         11243 non-null  object
#  5   Age               11243 non-null  float64
#  6   Marital_Status    11243 non-null  object
#  7   State             11243 non-null  object
#  8   Zone              11243 non-null  object
#  9   Occupation        11243 non-null  object
#  10  Product_Category  11243 non-null  object
#  11  Orders            11243 non-null  int64
#  12  Amount            11243 non-null  float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.2+ MB

# %%
df["Age Group"].value_counts().plot(kind="bar",color=["red","green"],width=0.3)
plt.xlabel("Age Group")
plt.title("barplot of Age Group")
# Out:
# Text(0.5, 1.0, 'barplot of Age Group')

# %% [markdown]
# from the age group 26-35 years of age the buyers are more for the diwali
#
# the  least age group are 0-17 years of the age
#
# 26-35>36-45>18-25>4-50>51-55>55+>0-17

# %%
sns.countplot(data=df,x="Age Group",width=0.3,palette=custom_palette)
plt.title("count plot of Age Group")
plt.show()
# Out:
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\2491928895.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x="Age Group",width=0.3,palette=custom_palette)
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\2491928895.py:1: UserWarning:
# The palette list has fewer values (4) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(data=df,x="Age Group",width=0.3,palette=custom_palette)

# %%
df["Age Group"].value_counts().plot(kind="pie",autopct="%1.2f")
plt.xlabel("Age Group")
plt.title("pie chart of Age Group")
# Out:
# Text(0.5, 1.0, 'pie chart of Age Group')

# %% [markdown]
# the above pie chart represents the age group of the buyers for diwali
#
# we can say that 26-35 years have 40.36% of the sales for the diwali

# %%
df["Marital_Status"].value_counts().plot(kind="bar",color=["red","green"],width=0.2)
plt.xlabel("Marital_Status")
plt.title("barplot of Marital_Status")
# Out:
# Text(0.5, 1.0, 'barplot of Marital_Status')

# %% [markdown]
# from the above bar plot we can say that
#
# married people are more when compared to the unmarried  people
#
# the married people around 6500 and unmarried people around 4700

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11243 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11243 non-null  int64
#  1   Cust_name         11243 non-null  object
#  2   Product_ID        11243 non-null  object
#  3   Gender            11243 non-null  object
#  4   Age Group         11243 non-null  object
#  5   Age               11243 non-null  float64
#  6   Marital_Status    11243 non-null  object
#  7   State             11243 non-null  object
#  8   Zone              11243 non-null  object
#  9   Occupation        11243 non-null  object
#  10  Product_Category  11243 non-null  object
#  11  Orders            11243 non-null  int64
#  12  Amount            11243 non-null  float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.2+ MB

# %%
sns.countplot(data=df,x="Marital_Status",width=0.3,palette=custom_palette)
plt.title("count plot of Marital_Status")
plt.show()
# Out:
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\2189621939.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x="Marital_Status",width=0.3,palette=custom_palette)
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\2189621939.py:1: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.countplot(data=df,x="Marital_Status",width=0.3,palette=custom_palette)

# %%
df["Marital_Status"].value_counts().plot(kind="pie",autopct="%1.2f")

plt.title("pie chart of Marital_Status")
# Out:
# Text(0.5, 1.0, 'pie chart of Marital_Status')

# %% [markdown]
# the married people has 57.97%
#
# the unmarried people has 42.03%

# %%
df["State"].value_counts().plot(kind="bar",color=["red","green"],width=0.2)
plt.xlabel("State")
plt.title("barplot of State")
# Out:
# Text(0.5, 1.0, 'barplot of State')

# %% [markdown]
# from the above bar plot we can say that
#
# from the people of uttar pradesh has the large amount of the buyers
#
# the least amount of the buyers are from the Telangana

# %%
df["State"].value_counts().plot(kind="pie",autopct="%1.2f")
plt.xlabel("State")
plt.title("pie chart of State")
# Out:
# Text(0.5, 1.0, 'pie chart of State')

# %% [markdown]
# from the uttarpradesh it is 17.29%
#
# from maharastra it is 13.55%
#
# the least are telangana it is 1.11%
#
# the second least it is Punjab it  is 1.78%

# %%
sns.countplot(data=df,x="State",width=0.3,palette=custom_palette)
plt.title("count plot of State")
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\2741726684.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x="State",width=0.3,palette=custom_palette)
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\2741726684.py:1: UserWarning:
# The palette list has fewer values (4) than needed (16) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(data=df,x="State",width=0.3,palette=custom_palette)

# %%
df["Zone"].value_counts().plot(kind="bar",color=["red","green"],width=0.2)
plt.xlabel("Zone")
plt.title("barplot of Zone")
# Out:
# Text(0.5, 1.0, 'barplot of Zone')

# %% [markdown]
# the central zone has the highest numbers
#
# the lowest are from the Eastern Zone
#
# central>southern>western>northren>eastren

# %%
sns.countplot(data=df,x="Zone",width=0.3,palette=custom_palette)
plt.title("count plot of Zone")
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\3095211032.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x="Zone",width=0.3,palette=custom_palette)
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\3095211032.py:1: UserWarning:
# The palette list has fewer values (4) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(data=df,x="Zone",width=0.3,palette=custom_palette)

# %%
df["Zone"].value_counts().plot(kind="pie",autopct="%1.2f")
plt.xlabel("Zone")
plt.title("pie chart of Zone")
# Out:
# Text(0.5, 1.0, 'pie chart of Zone')

# %% [markdown]
# the buyers from the eastern zone are 38.19
#
# the least buyers are from eastern zone are less that is 7.23

# %%
df["Occupation"].value_counts().plot(kind="bar",color=["red","green"],width=0.2)
plt.xlabel("Occupation")
plt.title("barplot of Occupation")
# Out:
# Text(0.5, 1.0, 'barplot of Occupation')

# %% [markdown]
# the more buyers are from the IT sector
#
# least buyers are from Agriculture

# %%
df["Occupation"].value_counts().plot(kind="pie",autopct="%1.2f")
plt.xlabel("Occupation")
plt.title("pie chart of Occupation")
# Out:
# Text(0.5, 1.0, 'pie chart of Occupation')

# %% [markdown]
# the more buyers are from it sector it is 14.11%
#
# the second highest is Healthcare it is 12.52

# %%
sns.countplot(data=df,x="Occupation",width=0.3,palette=custom_palette)
plt.title("count plot of Occupation")
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\234005063.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x="Occupation",width=0.3,palette=custom_palette)
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\234005063.py:1: UserWarning:
# The palette list has fewer values (4) than needed (15) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(data=df,x="Occupation",width=0.3,palette=custom_palette)

# %%
df["Product_Category"].value_counts().plot(kind="bar",color=["red","green"],width=0.2)
plt.xlabel("Product_Category")
plt.title("barplot of Product_Category")
# Out:
# Text(0.5, 1.0, 'barplot of Product_Category')

# %% [markdown]
# the most product sold for the diwali is Clothing & Apparel
#
# the third most product sold for the diwali is Electronics and Gadgets
#
# lest amount sold for the diwali is Hand & power tools

# %%
df["Product_Category"].value_counts().plot(kind="pie",autopct="%1.2f")
plt.xlabel("Product_Category")
plt.xticks(rotation=55)
plt.title("pie chart of Product_Category")
# Out:
# Text(0.5, 1.0, 'pie chart of Product_Category')

# %% [markdown]
# for the clothing and apparel it is around 23.60
#
# for second highest it is food

# %%
sns.countplot(data=df,x="Product_Category",width=0.3,palette=custom_palette)
plt.title("count plot of Product_Category")
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\2478772839.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x="Product_Category",width=0.3,palette=custom_palette)
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\2478772839.py:1: UserWarning:
# The palette list has fewer values (4) than needed (18) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(data=df,x="Product_Category",width=0.3,palette=custom_palette)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11243 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11243 non-null  int64
#  1   Cust_name         11243 non-null  object
#  2   Product_ID        11243 non-null  object
#  3   Gender            11243 non-null  object
#  4   Age Group         11243 non-null  object
#  5   Age               11243 non-null  float64
#  6   Marital_Status    11243 non-null  object
#  7   State             11243 non-null  object
#  8   Zone              11243 non-null  object
#  9   Occupation        11243 non-null  object
#  10  Product_Category  11243 non-null  object
#  11  Orders            11243 non-null  int64
#  12  Amount            11243 non-null  float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.2+ MB

# %%
df["Orders"].value_counts().plot(kind="bar",color=["red","green"],width=0.2)
plt.xlabel("Orders")
plt.title("barplot of Orders")
# Out:
# Text(0.5, 1.0, 'barplot of Orders')

# %% [markdown]
# for diwali for ordering two iteam there are more numbers
#
# the least amount of the ordering it is 3

# %%
df["Orders"].value_counts().plot(kind="pie",autopct="%1.2f")
plt.xlabel("Orders")
plt.xticks(rotation=55)
plt.title("pie chart of Orders")
# Out:
# Text(0.5, 1.0, 'pie chart of Orders')

# %% [markdown]
# from the pie chart we can say for ordering 1,2,3,4 are nearly equal

# %%
sns.countplot(data=df,x="Orders",width=0.3,palette=custom_palette)
plt.title("count plot of Orders")
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\275834412.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x="Orders",width=0.3,palette=custom_palette)

# %% [markdown]
# # Bivariate Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11243 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11243 non-null  int64
#  1   Cust_name         11243 non-null  object
#  2   Product_ID        11243 non-null  object
#  3   Gender            11243 non-null  object
#  4   Age Group         11243 non-null  object
#  5   Age               11243 non-null  float64
#  6   Marital_Status    11243 non-null  object
#  7   State             11243 non-null  object
#  8   Zone              11243 non-null  object
#  9   Occupation        11243 non-null  object
#  10  Product_Category  11243 non-null  object
#  11  Orders            11243 non-null  int64
#  12  Amount            11243 non-null  float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.2+ MB

# %%
pd.crosstab(index=df["Gender"],columns=df["Age Group"])
# Out:
# Age Group  0-17  18-25  26-35  36-45  46-50  51-55  55+
# Gender
# Female      162   1305   3268   1580    696    554  273
# Male        134    573   1270    705    291    277  155

# %% [markdown]
# from the age of 26-35 the more no of the female buyers
#
# from the age of 26-35 the more no of the male buyers
#
# the least amount of the buyers for the both male and the female the age is 0-17

# %%
sns.countplot(data=df,x="Gender",hue='Age Group',width=0.5,palette=custom_palette)
plt.title("relationship between the Gender and the Age Group")
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\113844847.py:1: UserWarning:
# The palette list has fewer values (4) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(data=df,x="Gender",hue='Age Group',width=0.5,palette=custom_palette)

# %% [markdown]
# from the above plot it is representing the relationship between the Gender and the Age Group
#
# we can see that 26-35 for the both male and female are high number of the buyers

# %%
pd.crosstab(index=df["Gender"],columns=df["Marital_Status"])
# Out:
# Marital_Status  Married  Unmarried
# Gender
# Female             4575       3263
# Male               1943       1462

# %% [markdown]
# from the above cross tab we can see that the married female and the male are the more numbers when compared to the unamerried male and female

# %%
sns.countplot(data=df,x="Gender",hue='Marital_Status',width=0.5,palette=custom_palette)
plt.title("relationship between the Gender and the marital status")
plt.show()
# Out:
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\2687019768.py:1: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.countplot(data=df,x="Gender",hue='Marital_Status',width=0.5,palette=custom_palette)

# %%
pd.crosstab(index=df["Gender"],columns=df["Occupation"])
# Out:
# Occupation  Agriculture  Automobile  Aviation  Banking  Chemical  \
# Gender
# Female              202         392       931      825       379
# Male                 80         174       378      314       163
#
# Occupation  Construction  Food Processing  Govt  Healthcare  Hospitality  \
# Gender
# Female               299              295   605         968          468
# Male                 114              128   249         440          234
#
# Occupation  IT Sector  Lawyer  Media  Retail  Textile
# Gender
# Female           1075     364    428     370      237
# Male              511     167    209     131      113

# %% [markdown]
# the female and male from the it sector has the more number of the buyers
#
# the female and male from the it sector has the less buyers from the Agriculture

# %%
sns.countplot(data=df,y="Gender",hue='Occupation',width=0.5,palette=custom_palette)
plt.title("relationship between the Gender and the ocupation")
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\2049458168.py:1: UserWarning:
# The palette list has fewer values (4) than needed (15) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(data=df,y="Gender",hue='Occupation',width=0.5,palette=custom_palette)

# %%
pd.crosstab(index=df["Gender"],columns=df["Product_Category"])
# Out:
# Product_Category  Auto  Beauty  Books  Clothing & Apparel  Decor  \
# Gender
# Female              66     325     39                1854     79
# Male                33      97     64                 799     17
#
# Product_Category  Electronics & Gadgets  Food  Footwear & Shoes  Furniture  \
# Gender
# Female                             1472  1774               786        220
# Male                                610   719               278        133
#
# Product_Category  Games & Toys  Hand & Power Tools  Household items  Office  \
# Gender
# Female                     273                   9              284      75
# Male                       113                  17              236      38
#
# Product_Category  Pet Care  Sports Products  Stationery  Tupperware  \
# Gender
# Female                 144              264          59          52
# Male                    68               92          53          20
#
# Product_Category  Veterinary
# Gender
# ...

# %% [markdown]
# the above shows the relationship between the gender and the product category
#
# the female and male from the clothing and apparel has the more number of the buyers
#
# the female and male from the Hand and power tools has the less buyers from the Agriculture

# %%
sns.countplot(data=df,y="Gender",hue='Product_Category',width=0.5,palette=custom_palette)
plt.title("count plot of Orders")
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\2847408628.py:1: UserWarning:
# The palette list has fewer values (4) than needed (18) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(data=df,y="Gender",hue='Product_Category',width=0.5,palette=custom_palette)

# %%
pd.crosstab(index=df["Gender"],columns=df["Orders"])
# Out:
# Orders     1     2     3     4
# Gender
# Female  1942  2014  1944  1938
# Male     870   881   821   833

# %% [markdown]
# the more no of the orders from the male and female are 2

# %%
sns.countplot(data=df,x="Gender",hue='Orders',width=0.5,palette=custom_palette)
plt.title("relationship between the Gender and Orders")

plt.show()

# %% [markdown]
# the female ordered more when compared to the male

# %%
pd.crosstab(index=df["State"],columns=df["Zone"])
# Out:
# Zone              Central  Eastern  Northern  Southern  Western
# State
# Andhra Pradesh          0        0         0       812        0
# Bihar                   0      433         0         0        0
# Delhi                1107        0         0         0        0
# Gujarat                 0        0         0         0      428
# Haryana                 0        0       451         0        0
# Himachal Pradesh        0        0       608         0        0
# Jharkhand               0      380         0         0        0
# Karnataka               0        0         0      1305        0
# Kerala                  0        0         0       453        0
# Madhya Pradesh        923        0         0         0        0
# Maharashtra             0        0         0         0     1523
# Punjab                  0        0       200         0        0
# Rajasthan               0        0       231         0        0
# Telangana               0        0         0       125        0
# ...

# %%
sns.countplot(data=df,x="State",hue='Zone',width=0.5,palette=custom_palette)
plt.title("relatinship between state and zone")
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\3821918821.py:1: UserWarning:
# The palette list has fewer values (4) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(data=df,x="State",hue='Zone',width=0.5,palette=custom_palette)

# %%
pd.crosstab(index=df["Age Group"],columns=df["Marital_Status"])
# Out:
# Marital_Status  Married  Unmarried
# Age Group
# 0-17                184        112
# 18-25              1077        801
# 26-35              2608       1930
# 36-45              1318        967
# 46-50               577        410
# 51-55               495        336
# 55+                 259        169

# %% [markdown]
# from the above table we can see that the more people around 26-35 are both married and unmarried

# %%
sns.countplot(data=df,x="Age Group",hue='Marital_Status',width=0.5,palette=custom_palette)
plt.title("Relationship between the Age Group and Marital Status")

plt.show()
# Out:
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\3643981710.py:1: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.countplot(data=df,x="Age Group",hue='Marital_Status',width=0.5,palette=custom_palette)

# %%
df.pivot_table(values="Amount",
              index="Gender",
              columns="Marital_Status",
              aggfunc="max")
# Out:
# Marital_Status  Married  Unmarried
# Gender
# Female          23314.0    23326.0
# Male            23247.0    23285.0

# %% [markdown]
# the maximum amount spent of for the married female is 23314
#
# the maximum amount spent of for the married male is 23247
#
# the maximum amount spent of for the unmarried female is 23326
#
# the maximum amount spent of for the unmarried male is 23285

# %%
df.pivot_table(values="Amount",
              index="Gender",
              columns="Marital_Status",
              aggfunc="mean")
# Out:
# Marital_Status      Married    Unmarried
# Gender
# Female          9547.457983  9337.169867
# Male            9404.228312  9226.534618

# %% [markdown]
# the mean amount spent of for the married female is 9547.457983
#
# the mean amount spent of for the married male is 9404.228312
#
# the mean amount spent of for the unmarried female is 9337.169867
#
# the mean amount spent of for the unmarried male is 9226.534618

# %%
df.pivot_table(values="Amount",
              index="Gender",
              columns="Marital_Status",
              aggfunc="min")
# Out:
# Marital_Status  Married  Unmarried
# Gender
# Female            188.0      381.0
# Male              206.0      370.0

# %% [markdown]
# the minimum amount spent of for the married female is 188.0
#
# the minimum amount spent of for the married male is 206.0
#
# the minimum amount spent of for the unmarried female is 381.0
#
# the minimum amount spent of for the unmarried male is 370.0

# %%
df.pivot_table(values="Amount",
              index="Gender",
              columns="Occupation",
              aggfunc="mean")
# Out:
# Occupation  Agriculture   Automobile     Aviation      Banking      Chemical  \
# Gender
# Female      9071.257426  9565.728599  9627.297530  9417.068087   9695.349897
# Male        9407.562500  9031.057471  9510.330688  9439.487261  10014.429448
#
# Occupation  Construction  Food Processing         Govt   Healthcare  \
# Gender
# Female       8653.842809      9577.210169  9851.446281  9249.725713
# Male         8663.429825      9504.273438  9983.710843  9241.715909
#
# Occupation  Hospitality    IT Sector       Lawyer         Media       Retail  \
# Gender
# Female      8937.593186  9470.023668  9255.554945  10188.514019  9647.018919
# Male        9229.199192  8936.361274  9570.395210   9190.444976  9156.297710
#
# Occupation      Textile
# Gender
# Female      9152.766291
# Male        9249.734513

# %% [markdown]
# the above table shows the relationship between the Gender and occupation with respect to mean

# %%
df.pivot_table(values="Amount",
              index="Gender",
              columns="Occupation",
              aggfunc="max")
# Out:
# Occupation  Agriculture  Automobile  Aviation  Banking  Chemical  \
# Gender
# Female          21463.0     23314.0   23270.0  23252.0   20955.0
# Male            23160.0     21320.0   23247.0  23246.0   20677.0
#
# Occupation  Construction  Food Processing     Govt  Healthcare  Hospitality  \
# Gender
# Female           20933.0          23326.0  21325.0     23302.0      21266.0
# Male             23103.0          23239.0  23285.0     21397.0      21039.0
#
# Occupation  IT Sector   Lawyer    Media   Retail  Textile
# Gender
# Female        23053.0  21533.0  23306.0  23066.0  21547.0
# Male          21563.0  20448.0  23281.0  20676.0  20925.0

# %% [markdown]
# the above table shows the relationship between the Gender and occupation with respect to max

# %%
df.groupby("Gender")["Amount"].mean()
# Out:
# Gender
# Female    9459.913951
# Male      9327.932224
# Name: Amount, dtype: float64

# %% [markdown]
# the mean amount for the female is 9459.913951
#
# the mean amount for the male is 9327.932224

# %%
df.groupby("Gender")[["Amount","Age"]].agg([np.mean,np.median,np.max])
# Out:
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\1935711529.py:1: FutureWarning: The provided callable <function mean at 0x000001F076560CC0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby("Gender")[["Amount","Age"]].agg([np.mean,np.median,np.max])
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\1935711529.py:1: FutureWarning: The provided callable <function median at 0x000001F07669CE00> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df.groupby("Gender")[["Amount","Age"]].agg([np.mean,np.median,np.max])
# ...

# %%
df.groupby("Occupation")[["Amount","Age"]].agg([np.mean,np.median,np.max])
# Out:
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\158082934.py:1: FutureWarning: The provided callable <function mean at 0x000001F076560CC0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby("Occupation")[["Amount","Age"]].agg([np.mean,np.median,np.max])
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\158082934.py:1: FutureWarning: The provided callable <function median at 0x000001F07669CE00> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df.groupby("Occupation")[["Amount","Age"]].agg([np.mean,np.median,np.max])
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11243 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11243 non-null  int64
#  1   Cust_name         11243 non-null  object
#  2   Product_ID        11243 non-null  object
#  3   Gender            11243 non-null  object
#  4   Age Group         11243 non-null  object
#  5   Age               11243 non-null  float64
#  6   Marital_Status    11243 non-null  object
#  7   State             11243 non-null  object
#  8   Zone              11243 non-null  object
#  9   Occupation        11243 non-null  object
#  10  Product_Category  11243 non-null  object
#  11  Orders            11243 non-null  int64
#  12  Amount            11243 non-null  float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.2+ MB

# %%
df.groupby("State")[["Amount","Age"]].agg([np.mean,np.median,np.max])
# Out:
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\3220101287.py:1: FutureWarning: The provided callable <function mean at 0x000001F076560CC0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby("State")[["Amount","Age"]].agg([np.mean,np.median,np.max])
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\3220101287.py:1: FutureWarning: The provided callable <function median at 0x000001F07669CE00> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df.groupby("State")[["Amount","Age"]].agg([np.mean,np.median,np.max])
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11243 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11243 non-null  int64
#  1   Cust_name         11243 non-null  object
#  2   Product_ID        11243 non-null  object
#  3   Gender            11243 non-null  object
#  4   Age Group         11243 non-null  object
#  5   Age               11243 non-null  float64
#  6   Marital_Status    11243 non-null  object
#  7   State             11243 non-null  object
#  8   Zone              11243 non-null  object
#  9   Occupation        11243 non-null  object
#  10  Product_Category  11243 non-null  object
#  11  Orders            11243 non-null  int64
#  12  Amount            11243 non-null  float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.2+ MB

# %%
df.groupby("Zone")[["Amount","Age"]].agg([np.mean,np.median,np.max])
# Out:
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\430197127.py:1: FutureWarning: The provided callable <function mean at 0x000001F076560CC0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby("Zone")[["Amount","Age"]].agg([np.mean,np.median,np.max])
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\430197127.py:1: FutureWarning: The provided callable <function median at 0x000001F07669CE00> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df.groupby("Zone")[["Amount","Age"]].agg([np.mean,np.median,np.max])
# ...

# %%
sns.lineplot(x=df["Age"],y=df["Amount"])
# Out:
# <Axes: xlabel='Age', ylabel='Amount'>

# %%
df.corr(numeric_only=True)
# Out:
#           User_ID       Age    Orders    Amount
# User_ID  1.000000  0.027714 -0.016220 -0.009316
# Age      0.027714  1.000000  0.005652  0.034924
# Orders  -0.016220  0.005652  1.000000 -0.012019
# Amount  -0.009316  0.034924 -0.012019  1.000000

# %%
sns.barplot(data=df,x="State",y="Amount",palette=custom_palette,estimator='sum')
plt.xticks(rotation=90)
plt.title("The Total amount spent by states")
plt.show()
# Out:
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\480522700.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df,x="State",y="Amount",palette=custom_palette,estimator='sum')
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\480522700.py:1: UserWarning:
# The palette list has fewer values (4) than needed (16) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(data=df,x="State",y="Amount",palette=custom_palette,estimator='sum')

# %%
sns.barplot(data=df,x="Zone",y="Amount",palette=custom_palette,estimator='sum')
plt.xticks(rotation=90)
plt.title("The Total amount spent by Zone")
plt.show()
# Out:
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\3758726120.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df,x="Zone",y="Amount",palette=custom_palette,estimator='sum')
# C:\Users\Ganji Bhaskar\AppData\Local\Temp\ipykernel_3720\3758726120.py:1: UserWarning:
# The palette list has fewer values (4) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(data=df,x="Zone",y="Amount",palette=custom_palette,estimator='sum')

# %%
sns.pairplot(data=df)

# %%
sns.scatterplot(data=df,x="Age",y="Amount")
# Out:
# <Axes: xlabel='Age', ylabel='Amount'>

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >
